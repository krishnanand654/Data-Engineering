# %% [markdown]
# #### 1. Pandas Basics

# %%
import pandas as pd

# %%
raw_data = pd.read_csv(r"C:\Users\Administrator\Downloads\Automobile_price_data__Raw_.csv")

# %%
raw_data.head() # first 5 data , default is 5, give parameter like head(2) will show the needed count
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
raw_data.tail() # last 5 data
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
raw_data.shape #shape returns tuples of size of rows and columns
# Out:
# (205, 26)

# %%
raw_data.columns #returns column names
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
raw_data.isnull() #isnull returns true  for missing data cell and False indicates no missing value
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
raw_data.notnull() #returns true for non-empty cell and False for missing values.
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True               True  True       True        True          True
# 1         True               True  True       True        True          True
# 2         True               True  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True               True  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 200       True               True  True       True        True          True
# 201       True               True  True       True        True          True
# 202       True               True  True       True        True          True
# 203       True               True  True       True        True          True
# 204       True               True  True       True        True          True
#
# ...

# %% [markdown]
# #### 2. Data Slicing
# - loc() and iloc()

# %%
raw_data.loc[1:10] #loc - label based indexing: Using row and column name data will be sliced
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# ...

# %%
#column slicing using loc(), 'make':'wheel-base'
raw_data.loc[:,'make':'wheel-base']
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
#     engine-location  wheel-base
# ...

# %%
raw_data.loc[1:10,'make':'wheel-base']
# Out:
#            make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 1   alfa-romero       gas        std          two  convertible          rwd
# 2   alfa-romero       gas        std          two    hatchback          rwd
# 3          audi       gas        std         four        sedan          fwd
# 4          audi       gas        std         four        sedan          4wd
# 5          audi       gas        std          two        sedan          fwd
# 6          audi       gas        std         four        sedan          fwd
# 7          audi       gas        std         four        wagon          fwd
# 8          audi       gas      turbo         four        sedan          fwd
# 9          audi       gas      turbo          two    hatchback          4wd
# 10          bmw       gas        std          two        sedan          rwd
#
#    engine-location  wheel-base
# 1            front        88.6
# 2            front        94.5
# 3            front        99.8
# ...

# %% [markdown]
# ``` raw_data.loc[:,:]  ```
# all rows and columns

# %%
raw_data.loc[[1,3,5,7],['make','aspiration','drive-wheels', 'wheel-base']] #non sequence
# Out:
#           make aspiration drive-wheels  wheel-base
# 1  alfa-romero        std          rwd        88.6
# 3         audi        std          fwd        99.8
# 5         audi        std          fwd        99.8
# 7         audi        std          fwd       105.8

# %%
#integer based label indexing: using rows and columns index position data will be sliced
raw_data.iloc[1:10] #start index = 1 and end index = 9
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 1  convertible          rwd           front        88.6  ...          130
# ...

# %% [markdown]
# ``` raw_data.iloc[:,:]  ```
# Selecting all rows and columns

# %%
raw_data.iloc[:,2:12] #slicing columns by using integer index, start=2 and end=11
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %% [markdown]
# ##### Summary
#  - raw_data.iloc[raw_index, column_index]
#  - raw_data.loc[raw_label, column_label]

# %% [markdown]
# #### 3. Rows and column selection

# %%
 #Single column selection: Slicing one column
raw_data['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
#selecting muliple columns by using column-list
raw_data[['make','wheel-base']]
# Out:
#             make  wheel-base
# 0    alfa-romero        88.6
# 1    alfa-romero        88.6
# 2    alfa-romero        94.5
# 3           audi        99.8
# 4           audi        99.4
# ..           ...         ...
# 200        volvo       109.1
# 201        volvo       109.1
# 202        volvo       109.1
# 203        volvo       109.1
# 204        volvo       109.1
#
# [205 rows x 2 columns]

# %% [markdown]
# #### 4. Filter

# %%
raw_data['make'] == 'audi' #This is a boolean condition returns True if condition is True else False.(acts as an if condition)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: make, Length: 205, dtype: bool

# %%
raw_data[raw_data['make'] == 'audi'] #Return the data based on a condition
# Out:
#    symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2               164  audi       gas        std         four
# 4          2               164  audi       gas        std         four
# 5          2                 ?  audi       gas        std          two
# 6          1               158  audi       gas        std         four
# 7          1                 ?  audi       gas        std         four
# 8          1               158  audi       gas      turbo         four
# 9          0                 ?  audi       gas      turbo          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3      sedan          fwd           front        99.8  ...          109
# 4      sedan          4wd           front        99.4  ...          136
# 5      sedan          fwd           front        99.8  ...          136
# 6      sedan          fwd           front       105.8  ...          136
# ...

# %%
#slicing datafrome using multiple condition
raw_data[(raw_data['make'] == 'toyota') & (raw_data['body-style'] == 'sedan')]
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 156          0                91  toyota       gas        std         four
# 158          0                91  toyota    diesel        std         four
# 160          0                91  toyota       gas        std         four
# 162          0                91  toyota       gas        std         four
# 163          1               168  toyota       gas        std          two
# 165          1               168  toyota       gas        std          two
# 173         -1                65  toyota       gas        std         four
# 174         -1                65  toyota    diesel      turbo         four
# 176         -1                65  toyota       gas        std         four
# 180         -1                90  toyota       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# data display when either of the two condition is True
raw_data[(raw_data['make'] == 'toyota') | (raw_data['body-style'] == 'sedan')]
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 5            2                 ?   audi       gas        std          two
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# #### 5. Sorting

# %%
#sort by ascending order
raw_data['wheel-base'].sort_values()
# Out:
# 31      86.6
# 30      86.6
# 18      88.4
# 0       88.6
# 1       88.6
#        ...
# 113    114.2
# 114    114.2
# 71     115.6
# 70     115.6
# 73     120.9
# Name: wheel-base, Length: 205, dtype: float64

# %%
#Sorting wheel-base in Descending order
raw_data['wheel-base'].sort_values(ascending = False)
# Out:
# 73     120.9
# 71     115.6
# 70     115.6
# 114    114.2
# 113    114.2
#        ...
# 1       88.6
# 0       88.6
# 18      88.4
# 30      86.6
# 31      86.6
# Name: wheel-base, Length: 205, dtype: float64

# %%
 #Sort dataframe by engine size
raw_data.sort_values(by = 'engine-size')
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 18          2               121      chevrolet       gas        std
# 57          3               150          mazda       gas        std
# 55          3               150          mazda       gas        std
# 56          3               150          mazda       gas        std
# 32          1               101          honda       gas        std
# ..        ...               ...            ...       ...        ...
# 48          0                 ?         jaguar       gas        std
# 47          0               145         jaguar       gas        std
# 74          1                 ?  mercedes-benz       gas        std
# 73          0                 ?  mercedes-benz       gas        std
# 49          0                 ?         jaguar       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 18          two  hatchback          fwd           front        88.4  ...
# ...

# %%
#First sort by make and then by engine-size, if make is same then sort the engine_size
raw_data.sort_values(by = ['make','engine-size']).head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
#make in descending order and for that make the engine-size will be in ascending order
raw_data.sort_values(by = ['make','engine-size'],ascending = [False, True]).head(20)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 198         -2               103       volvo       gas      turbo
# 199         -1                74       volvo       gas      turbo
# 194         -2               103       volvo       gas        std
# 195         -1                74       volvo       gas        std
# 196         -2               103       volvo       gas        std
# 197         -1                74       volvo       gas        std
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 204         -1                95       volvo       gas      turbo
# 203         -1                95       volvo    diesel      turbo
# 202         -1                95       volvo       gas        std
# 182          2               122  volkswagen    diesel        std
# 184          2                94  volkswagen    diesel        std
# ...

# %%
#show all unique values of makers
raw_data['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
#frequency of each category
raw_data['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# #### 6. Filter and Query
# - filter() is used for primarily used for subset the rows and columns of the selected DataFrame

# %%
# if num is present in the data it will be displayed
raw_data.filter(like="num")
# Out:
#     num-of-doors num-of-cylinders
# 0            two             four
# 1            two             four
# 2            two              six
# 3           four             four
# 4           four             five
# ..           ...              ...
# 200         four             four
# 201         four             four
# 202         four              six
# 203         four              six
# 204         four             four
#
# [205 rows x 2 columns]

# %%
# slicing columns by using column labels
raw_data.filter(items = ['make','num-of-doors', 'horsepower'])
# Out:
#             make num-of-doors horsepower
# 0    alfa-romero          two        111
# 1    alfa-romero          two        111
# 2    alfa-romero          two        154
# 3           audi         four        102
# 4           audi         four        115
# ..           ...          ...        ...
# 200        volvo         four        114
# 201        volvo         four        160
# 202        volvo         four        134
# 203        volvo         four        106
# 204        volvo         four        114
#
# [205 rows x 3 columns]

# %%
# slicing rows by row label and axis = 0 (indicating row wise) axis = 1 (default: column wise)
raw_data.filter(items = [0,1,3,4], axis=0)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
#slicing column by ^ which indicates start of column name.
raw_data.filter(regex = r'^a')
# Out:
#     aspiration
# 0          std
# 1          std
# 2          std
# 3          std
# 4          std
# ..         ...
# 200        std
# 201      turbo
# 202        std
# 203      turbo
# 204      turbo
#
# [205 rows x 1 columns]

# %%
raw_data.query(" `make` == 'toyota' and `engine-size` >= 130")
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 167          2               134  toyota       gas        std          two
# 168          2               134  toyota       gas        std          two
# 169          2               134  toyota       gas        std          two
# 170          2               134  toyota       gas        std          two
# 171          2               134  toyota       gas        std          two
# 172          2               134  toyota       gas        std          two
# 178          3               197  toyota       gas        std          two
# 179          3               197  toyota       gas        std          two
# 180         -1                90  toyota       gas        std         four
# 181         -1                 ?  toyota       gas        std         four
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# #### 7. Handling missing values
# - mean if data is continous
# - median if data is continous or discrete
# - mode if data is categorical
# - avoided is missing data more than 5%
# - more than 20% remove column

# %%
import numpy as np

# %%
#replace '? ' by 'nan' and update DataFrame
raw_data.replace('?', np.nan, inplace = True)

# %%
# returns total missing values from each columns
raw_data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Handling the missing values

# %%
#Display missing values percentage
raw_data.isnull().sum() / raw_data.shape[0] * 100
# Out:
# symboling             0.00000
# normalized-losses    20.00000
# make                  0.00000
# fuel-type             0.00000
# aspiration            0.00000
# num-of-doors          0.97561
# body-style            0.00000
# drive-wheels          0.00000
# engine-location       0.00000
# wheel-base            0.00000
# length                0.00000
# width                 0.00000
# height                0.00000
# curb-weight           0.00000
# engine-type           0.00000
# num-of-cylinders      0.00000
# engine-size           0.00000
# fuel-system           0.00000
# bore                  1.95122
# stroke                1.95122
# compression-ratio     0.00000
# horsepower            0.97561
# peak-rpm              0.97561
# city-mpg              0.00000
# highway-mpg           0.00000
# price                 1.95122
# dtype: float64

# %%
#drop columns by using column names
raw_data.drop(['symboling', 'normalized-losses'], axis=1, inplace = True)

# %%
raw_data['price'].dtype
# Out:
# dtype('O')

# %%
raw_data['price'] = raw_data['price'].astype('float64')

# %%
raw_data['price'].dtype
# Out:
# dtype('float64')

# %%
vehicle_df = raw_data.copy()

# %%
vehicle_df
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
#median
vehicle_df['price'].median()
# Out:
# 10295.0

# %%
#fill the nan (missing values) in price with the median of price
vehicle_df['price'] = vehicle_df['price'].fillna(vehicle_df['price'].median())

# %%
vehicle_df
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
vehicle_df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#Drop missing row from all column
vehicle_df.dropna(inplace = True)

# %%
vehicle_df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# #### 8. Drop duplicates
# - drop diplicate values

# %%
dict(vehicle_df.loc[10])
# Out:
# {'make': 'bmw',
#  'fuel-type': 'gas',
#  'aspiration': 'std',
#  'num-of-doors': 'two',
#  'body-style': 'sedan',
#  'drive-wheels': 'rwd',
#  'engine-location': 'front',
#  'wheel-base': 101.2,
#  'length': 176.8,
#  'width': 64.8,
#  'height': 54.3,
#  'curb-weight': 2395,
#  'engine-type': 'ohc',
#  'num-of-cylinders': 'four',
#  'engine-size': 108,
#  'fuel-system': 'mpfi',
#  'bore': '3.50',
#  'stroke': '2.80',
#  'compression-ratio': 8.8,
#  'horsepower': '101',
#  'peak-rpm': '5800',
#  'city-mpg': 23,
#  'highway-mpg': 29,
#  'price': 16430.0}

# %%
#select random sample from DataFrame using frac = 0.05 (5%) or n = num of samples
sample_df = vehicle_df.sample(frac=0.05)

# %%
#combining with another dataFrame
vehicle_df = pd.concat([vehicle_df, sample_df], ignore_index = True)

# %%
vehicle_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 202     True
# 203     True
# 204     True
# 205     True
# 206     True
# Length: 207, dtype: bool

# %%
vehicle_df[vehicle_df.duplicated()]
# Out:
#            make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 197      nissan    diesel        std          two      sedan          fwd
# 198      subaru       gas        std         four      wagon          fwd
# 199       mazda       gas        std          two  hatchback          fwd
# 200      nissan       gas        std          two      sedan          fwd
# 201  volkswagen    diesel      turbo         four      sedan          fwd
# 202      subaru       gas        std          two  hatchback          fwd
# 203      nissan       gas        std         four      wagon          fwd
# 204       honda       gas        std          two      sedan          fwd
# 205  volkswagen       gas        std          two  hatchback          fwd
# 206      peugot       gas      turbo         four      sedan          rwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# ...

# %%
#Drop all duplicated datas from the DataFrame
vehicle_df.drop_duplicates(inplace = True)

# %%
vehicle_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# Length: 197, dtype: bool

# %%
vehicle_df[vehicle_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# #### 9. Group By
# - Used for the aggregate operations.

# %%
#to the find the avg price in each make
vehicle_df.groupby('make')['price'].mean()
# Out:
# make
# alfa-romero      15498.333333
# audi             16778.571429
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7790.125000
# honda             8184.692308
# isuzu             9605.750000
# jaguar           34600.000000
# mazda             9852.000000
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          27179.400000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64

# %%
#to the find the avg price in each make
vehicle_df.groupby('make')[['price','city-mpg']].mean()
# vehicle_df.groupby('make')[['price','city-mpg']].sum()
# vehicle_df.groupby('make')[['price','city-mpg']].max()
# Out:
#                       price   city-mpg
# make
# alfa-romero    15498.333333  20.333333
# audi           16778.571429  18.857143
# bmw            26118.750000  19.375000
# chevrolet       6007.000000  41.000000
# dodge           7790.125000  28.500000
# honda           8184.692308  30.384615
# isuzu           9605.750000  31.000000
# jaguar         34600.000000  14.333333
# mazda           9852.000000  27.833333
# mercedes-benz  33647.000000  18.500000
# mercury        16503.000000  19.000000
# mitsubishi      9239.769231  24.923077
# nissan         10415.666667  27.000000
# peugot         15489.090909  22.454545
# plymouth        7963.428571  28.142857
# porsche        27179.400000  17.400000
# saab           15223.333333  20.333333
# subaru          8541.250000  26.333333
# toyota          9885.812500  27.500000
# volkswagen     10077.500000  28.583333
# volvo          18063.181818  21.181818

# %%
vehicle_df.groupby('make')[['price','city-mpg']].max().sort_values(by='price', ascending = False)
# Out:
#                  price  city-mpg
# make
# mercedes-benz  45400.0        22
# bmw            41315.0        23
# porsche        37028.0        19
# jaguar         36000.0        15
# audi           23875.0        24
# volvo          22625.0        26
# nissan         19699.0        45
# saab           18620.0        21
# mazda          18344.0        31
# peugot         18150.0        28
# toyota         17669.0        38
# mercury        16503.0        19
# alfa-romero    16500.0        21
# mitsubishi     14869.0        37
# volkswagen     13845.0        37
# dodge          12964.0        37
# honda          12945.0        49
# plymouth       12764.0        37
# subaru         11694.0        32
# isuzu          11048.0        38
# chevrolet       6575.0        47

# %% [markdown]
# #### 10. apply()
# - used to modfy the column values.

# %%
vehicle_df1 = vehicle_df.copy()

# %%
vehicle_df1['Dimension'] = vehicle_df1.apply(lambda row: row['length'] * row['width'], axis = 1)

# %%
vehicle_df1
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 192        volvo       gas        std         four        sedan          rwd
# 193        volvo       gas      turbo         four        sedan          rwd
# 194        volvo       gas        std         four        sedan          rwd
# 195        volvo    diesel      turbo         four        sedan          rwd
# 196        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %% [markdown]
# #### 11. set and reset index

# %%
city = {
    'United States': 76100,
    'China': 13000,
    'Germany': 47000,
    'India': 2200,
    'Brazil': 10500,
    'Canada': 54000,
    'France': 42000,
    'Japan': 43000,
    'Australia': 62000,
    'South Africa': 6700,
    'Russia': 10500,
    'Mexico': 9500,
    'South Korea': 34000,
    'Italy': 35000,
    'United Kingdom': 49000
}

city_series = pd.Series(city)

# %%
city_gdp = pd.DataFrame(city_series, columns=['gdp_per_capita'])

# %%
city_gdp
# Out:
#                 gdp_per_capita
# United States            76100
# China                    13000
# Germany                  47000
# India                     2200
# Brazil                   10500
# Canada                   54000
# France                   42000
# Japan                    43000
# Australia                62000
# South Africa              6700
# Russia                   10500
# Mexico                    9500
# South Korea              34000
# Italy                    35000
# United Kingdom           49000

# %%
#reset_index will create new index and add the existing index as a new column
city_gdp = city_gdp.reset_index()

# %%
city_gdp
# Out:
#              index  gdp_per_capita
# 0    United States           76100
# 1            China           13000
# 2          Germany           47000
# 3            India            2200
# 4           Brazil           10500
# 5           Canada           54000
# 6           France           42000
# 7            Japan           43000
# 8        Australia           62000
# 9     South Africa            6700
# 10          Russia           10500
# 11          Mexico            9500
# 12     South Korea           34000
# 13           Italy           35000
# 14  United Kingdom           49000

# %%
#To choose the column as an index
city_gdp.set_index('index')
# Out:
#                 gdp_per_capita
# index
# United States            76100
# China                    13000
# Germany                  47000
# India                     2200
# Brazil                   10500
# Canada                   54000
# France                   42000
# Japan                    43000
# Australia                62000
# South Africa              6700
# Russia                   10500
# Mexico                    9500
# South Korea              34000
# Italy                    35000
# United Kingdom           49000

# %% [markdown]
# #### 12. Pivot Table

# %%
#implementing: categorical values to create another table for insightful informations
vehicle_df1.pivot_table(values = 'price', index = 'drive-wheels',columns='body-style', aggfunc='mean')
# Out:
# body-style    convertible       hardtop     hatchback         sedan  \
# drive-wheels
# 4wd                   NaN           NaN   8949.000000  12647.333333
# fwd               11595.0   8249.000000   8365.166667   9834.290909
# rwd               23949.6  24202.714286  14419.666667  21711.833333
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd           10061.181818
# rwd           16994.222222

# %%
vehicle_df1.pivot_table(values = 'price', index = ['drive-wheels','engine-location'],columns='body-style', aggfunc='mean')
# Out:
# body-style                    convertible  hardtop     hatchback  \
# drive-wheels engine-location
# 4wd          front                    NaN      NaN   8949.000000
# fwd          front                11595.0   8249.0   8365.166667
# rwd          front                20680.0  20572.6  14419.666667
#              rear                 37028.0  33278.0           NaN
#
# body-style                           sedan         wagon
# drive-wheels engine-location
# 4wd          front            12647.333333   9095.750000
# fwd          front             9834.290909  10061.181818
# rwd          front            21711.833333  16994.222222
#              rear                      NaN           NaN

# %% [markdown]
# #### 13. Merge

# %%
df_series1 = pd.Series({
    "United States": 12313,
    "Canada": 45700,
    "Germany": 46200,
    "United Kingdom": 46200,
    "Japan": 41400
}, name = 'GDP_per_captia')

# %%
df_series2 = pd.Series({
    "United States": 1232343213,
    "Canada": 4572300,
    "Germany": 46232400,
    "United Kingdom": 412126200,
    "Japan": 4123400
}, name = 'population')

# %%
df1 = pd.DataFrame(df_series1).reset_index()

# %%
df1.columns = ['country','gpd_per_capita']

# %%
df1
# Out:
#           country  gpd_per_capita
# 0   United States           12313
# 1          Canada           45700
# 2         Germany           46200
# 3  United Kingdom           46200
# 4           Japan           41400

# %%
df2 = pd.DataFrame(df_series2).reset_index()

# %%
#rename existing column
df2.columns = ['country','population']

# %%
df2
# Out:
#           country  population
# 0   United States  1232343213
# 1          Canada     4572300
# 2         Germany    46232400
# 3  United Kingdom   412126200
# 4           Japan     4123400

# %%
#how : how to joing "inner, left, right, outer"
pd.merge(df1, df2, on='country', how='inner')
# Out:
#           country  gpd_per_capita  population
# 0   United States           12313  1232343213
# 1          Canada           45700     4572300
# 2         Germany           46200    46232400
# 3  United Kingdom           46200   412126200
# 4           Japan           41400     4123400

# %% [markdown]
# #### 14. CrossTab
# - Cross tabulation is panda method to create contingency table, that shows the frequency distribution of attributes

# %%
pd.crosstab(vehicle_df1['body-style'], vehicle_df1['num-of-doors'])
# Out:
# num-of-doors  four  two
# body-style
# convertible      0    6
# hardtop          0    8
# hatchback       10   55
# sedan           79   15
# wagon           24    0
