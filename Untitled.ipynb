# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/Administrator/Downloads/Titanic.csv")

# %%
data['Sex'].value_counts() / data.shape[0] * 100
# Out:
# Sex
# male      52.7
# female    47.3
# Name: count, dtype: float64

# %%
plt.pie(data['Sex'].value_counts() / data.shape[0] * 100, autopct = "%0.2f%%", labels=data['Sex'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x294b03722d0>,
# ...
#  [Text(-0.0931934888363163, 1.0960451512773166, 'male'),
#   Text(0.09319348883631616, -1.0960451512773166, 'female')],
#  [Text(-0.05083281209253616, 0.5978428097876272, '52.70%'),
#   Text(0.05083281209253609, -0.5978428097876272, '47.30%')])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Pclass       1000 non-null   int64
#  2   Name         1000 non-null   object
#  3   Sex          1000 non-null   object
#  4   Age          1000 non-null   int64
#  5   SibSp        1000 non-null   int64
#  6   Parch        1000 non-null   int64
#  7   Ticket       1000 non-null   object
#  8   Fare         1000 non-null   float64
#  9   Embarked     1000 non-null   object
#  10  Survived     1000 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 86.1+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %%
data.isnull()
# Out:
#      PassengerId  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False   False  False  False  False  False  False   False  False
# 1          False   False  False  False  False  False  False   False  False
# 2          False   False  False  False  False  False  False   False  False
# 3          False   False  False  False  False  False  False   False  False
# 4          False   False  False  False  False  False  False   False  False
# ..           ...     ...    ...    ...    ...    ...    ...     ...    ...
# 995        False   False  False  False  False  False  False   False  False
# 996        False   False  False  False  False  False  False   False  False
# 997        False   False  False  False  False  False  False   False  False
# 998        False   False  False  False  False  False  False   False  False
# 999        False   False  False  False  False  False  False   False  False
#
#      Embarked  Survived
# 0       False     False
# ...

# %%
data.head()
# Out:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
df_numerical = data.select_dtypes(include='number')

# %%
df_numerical
# Out:
#      PassengerId  Pclass  Age  SibSp  Parch    Fare  Survived
# 0              1       3   17      4      2  144.08         1
# 1              2       1   60      2      2  249.04         0
# 2              3       3   64      0      0   50.31         1
# 3              4       3   35      4      0  235.20         1
# 4              5       1   70      0      3  160.17         1
# ..           ...     ...  ...    ...    ...     ...       ...
# 995          996       2   69      2      3   19.87         1
# 996          997       2   61      4      4   85.35         0
# 997          998       3   10      4      1  444.22         0
# 998          999       3   50      3      2  234.67         1
# 999         1000       1    3      3      3  286.65         1
#
# [1000 rows x 7 columns]

# %%
df_categorical = data.select_dtypes(include='object')

# %%
df_categorical
# Out:
#                   Name     Sex                                Ticket Embarked
# 0         Allison Hill    male  43d75413-a939-4bd1-a516-b0d47d3572cc        Q
# 1          Noah Rhodes    male  6334fa2a-8b4b-47e7-a451-5ae01754bf08        S
# 2      Angie Henderson    male  61a66444-e2af-4629-9efb-336e2f546033        Q
# 3        Daniel Wagner    male  0b6c03c8-721e-4419-afc3-e6495e911b91        C
# 4      Cristian Santos  female  436e3c49-770e-49db-b092-d40143675d58        C
# ..                 ...     ...                                   ...      ...
# 995      Brittany Ward    male  75eb0e8f-a090-460d-a7c7-655a7b434a72        Q
# 996     Edward Stanley  female  e55b93ad-8976-4471-9d7f-57d1e45def26        C
# 997  Christina Johnson    male  d06d3943-c8b3-415e-b664-704355c9bf0f        C
# 998       Edgar Miller    male  0e5779ec-be1a-470f-ad83-a4c869f8d3e4        S
# 999  Elizabeth Sanders    male  90a014ab-4ca1-4abd-8565-0e0bd5c97d5d        C
#
# [1000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
df_numerical
# Out:
#      PassengerId  Pclass  Age  SibSp  Parch    Fare  Survived
# 0              1       3   17      4      2  144.08         1
# 1              2       1   60      2      2  249.04         0
# 2              3       3   64      0      0   50.31         1
# 3              4       3   35      4      0  235.20         1
# 4              5       1   70      0      3  160.17         1
# ..           ...     ...  ...    ...    ...     ...       ...
# 995          996       2   69      2      3   19.87         1
# 996          997       2   61      4      4   85.35         0
# 997          998       3   10      4      1  444.22         0
# 998          999       3   50      3      2  234.67         1
# 999         1000       1    3      3      3  286.65         1
#
# [1000 rows x 7 columns]

# %%
plt.plot(df_numerical['Age'].sort_values().unique())

# %%
data[(df_numerical['Survived'] == 1) & (df_categorical['Sex'] == 'male')]
# Out:
#      PassengerId  Pclass               Name   Sex  Age  SibSp  Parch  \
# 0              1       3       Allison Hill  male   17      4      2
# 2              3       3    Angie Henderson  male   64      0      0
# 3              4       3      Daniel Wagner  male   35      4      0
# 5              6       1    Connie Lawrence  male   30      2      3
# 8              9       3    Gabrielle Davis  male   63      4      1
# ..           ...     ...                ...   ...  ...    ...    ...
# 989          990       2      Karen Johnson  male   70      1      4
# 990          991       2     Carmen Preston  male   47      0      1
# 995          996       2      Brittany Ward  male   69      2      3
# 998          999       3       Edgar Miller  male   50      3      2
# 999         1000       1  Elizabeth Sanders  male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# 0    43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# ...

# %%
data.pivot_table(values = 'Fare', index = 'Embarked',columns='Sex', aggfunc='mean')
# Out:
# Sex           female        male
# Embarked
# C         239.147438  259.784821
# Q         237.086386  247.803367
# S         253.434150  250.801166

# %%
data_count =df_categorical['Sex'].value_counts()

# %%
data_count[1]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8428\65258745.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_count[1]
# 473

# %%
netflix_df = pd.read_csv("C:/Users/Administrator/Downloads/netflix1.csv", low_memory=False)

# %%
netflix_df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
rating = netflix_df['rating'].value_counts().sort_values(ascending= False)[:5].index
rating_count = netflix_df['rating'].value_counts().sort_values(ascending= False)[:5].values

# %%
sns.barplot(x = rating, y = rating_count, color="red")
# Out:
# <Axes: xlabel='rating'>

# %%
netflix_df['type'].value_counts() / netflix_df.shape[0] * 100
# Out:
# type
# Movie      69.692833
# TV Show    30.307167
# Name: count, dtype: float64

# %%
plt.pie(netflix_df['type'].value_counts() / netflix_df.shape[0] * 100, autopct="%0.02f%%", labels=netflix_df['type'].unique(), colors=['red','mistyrose'])
plt.legend()
my_circle=plt.Circle( (0,0), 0.8, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
sns.distplot(netflix_df.groupby('type')['release_year'].value_counts())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3572\3295317179.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(netflix_df.groupby('type')['release_year'].value_counts())
# <Axes: xlabel='count', ylabel='Density'>
